# %%
import pandas as pd
from sqlalchemy import create_engine
df=pd.read_excel("../Data/churn.xlsx")

# %%
df
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0             1    15565701     Ferri          698     Spain  Female   39
# 1             2    15565706  Akobundu          612     Spain    Male   35
# 2             3    15565714  Cattaneo          601    France    Male   47
# 3             4    15565779      Kent          627   Germany  Female   30
# 4             5    15565796  Docherty          745   Germany    Male   48
# ...         ...         ...       ...          ...       ...     ...  ...
# 9995       9996    15815628    Moysey          711    France  Female   37
# 9996       9997    15815645    Akhtar          481    France    Male   37
# 9997       9998    15815656   Hopkins          541   Germany  Female   39
# 9998       9999    15815660     Mazzi          758    France  Female   34
# 9999      10000    15815690  Akabueze          614     Spain  Female   40
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          9  161993.89              1          0               0
# 1          1       0.00              1          1               1
# 2          1   64430.06              2          0               1
# 3          6   57809.32              1          1               0
# 4         10   96048.55              1          1               0
# ...      ...        ...            ...        ...             ...
# 9995       8  113899.92              1          0               0
# 9996       8  152303.66              2          1               1
# 9997       9  100116.67              1          1               1
# 9998       1  154139.45              1          1               1
# 9999       3  113348.50              1          1               1
#
#       EstimatedSalary  Exited  Churn   Churn.1     Active  Age Group
# 0            90212.38       0    NaN  No-Churn  Not Active     35-45
# 1            83256.26       1  Churn       NaN      Active     35-45
# 2            96517.97       0    NaN  No-Churn      Active       45+
# 3           188258.49       0    NaN  No-Churn  Not Active     25-35
# 4            74510.65       0    NaN  No-Churn  Not Active       45+
# ...               ...     ...    ...       ...         ...       ...
# 9995         80215.20       0    NaN  No-Churn  Not Active     35-45
# 9996        175082.20       0    NaN  No-Churn      Active     35-45
# 9997        199808.10       1  Churn       NaN      Active     35-45
# 9998         60728.89       0    NaN  No-Churn      Active     25-35
# 9999         77789.01       0    NaN  No-Churn      Active     35-45
#
# [10000 rows x 18 columns]

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15565701     Ferri          698     Spain  Female   39
# 1          2    15565706  Akobundu          612     Spain    Male   35
# 2          3    15565714  Cattaneo          601    France    Male   47
# 3          4    15565779      Kent          627   Germany  Female   30
# 4          5    15565796  Docherty          745   Germany    Male   48
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       9  161993.89              1          0               0
# 1       1       0.00              1          1               1
# 2       1   64430.06              2          0               1
# 3       6   57809.32              1          1               0
# 4      10   96048.55              1          1               0
#
#    EstimatedSalary  Exited  Churn   Churn.1     Active  Age Group
# 0         90212.38       0    NaN  No-Churn  Not Active     35-45
# 1         83256.26       1  Churn       NaN      Active     35-45
# 2         96517.97       0    NaN  No-Churn      Active       45+
# 3        188258.49       0    NaN  No-Churn  Not Active     25-35
# 4         74510.65       0    NaN  No-Churn  Not Active       45+

# %%
df.isnull().sum()
# Out:
# RowNumber             0
# CustomerId            0
# Surname               0
# CreditScore           0
# Geography             0
# Gender                0
# Age                   0
# Tenure                0
# Balance               0
# NumOfProducts         0
# HasCrCard             0
# IsActiveMember        0
# EstimatedSalary       0
# Exited                0
# Churn              7963
# Churn.1            2037
# Active                0
# Age Group             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# Churn               object
# Churn.1             object
# Active              object
# Age Group           object
# dtype: object

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited', 'Churn', 'Churn.1',
#        'Active ', 'Age Group'],
#       dtype='object')

# %%
df.drop(columns=("Active "),inplace=True)

# %%
df.columns=df.columns.str.replace(" ","_")

# %%
engine=create_engine(
    "mysql+pymysql://root:password@localhost/testd"
)

# %%
df.to_sql(
"churn",
con=engine,
if_exists="replace",
index=False
)
# Out:
# 10000
